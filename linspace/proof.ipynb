# %%
from numpy import frompyfunc, linspace, sqrt, exp, log, pi, zeros, arange
from mpmath import polylog
from scipy.integrate import quad
from pylab import cm
from matplotlib.ticker import AutoMinorLocator

# Call plotting library
import matplotlib as mpl
import matplotlib.pyplot as plt

import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib.gridspec as gs
import sys

npoint = 301
eta = linspace(-0.6, 0.6, npoint) 
fc = 0.4543*np.abs(eta)
fv = -14.473*(abs(eta))**2/(2*1.45)

fig=plt.figure(figsize=(12,8))
ax=fig.add_subplot(111)
ax.plot(eta,fc,c='red')
ax.plot(eta,fv+0.375,c='green')
