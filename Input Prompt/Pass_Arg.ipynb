# %%
def add(a, b):
  """Returns the sum of two numbers."""
  return a + b

# Call the add() function and pass it the arguments 1 and 2.
result = add(1, 2)

# Print the result.
print(result)
# Out:
# 3

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5E53-193A
#
#  Directory of c:\Users\HP\Documents\GitHub\My-Python
#
# 10/19/2023  02:39 PM    <DIR>          .
# 10/19/2023  02:39 PM    <DIR>          ..
# 10/19/2023  02:40 PM               707 Pass_Arg.ipynb
# 10/19/2023  02:39 PM                53 README.md
#                2 File(s)            760 bytes
#                2 Dir(s)  287,441,702,912 bytes free
