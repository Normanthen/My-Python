# %% [markdown]
# # Student Data
# This notebook analyzes pass/fail data for a class

# %%
import numpy as np

data = [50,50,47,97,49,3]
grades = np.array(data)
study_hours = [10.0, 11.5, 9.0, 16.0, 9.25, 1.0]
student_data = np.array([study_hours, grades])
student_data[0][0]
# Out:
# 10.0

# %%
import pandas as pd

df_students = pd.DataFrame({'Name': ['Dan', 'Joann', 'Pedro','Rosie', 'Ethan', 'Vicky'], 
                            'StudyHours': student_data[0],
                            'Grade': student_data[1]})

df_students
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0
# 5  Vicky        1.00    3.0

# %%
df_students.loc[0]
# Out:
# Name           Dan
# StudyHours    10.0
# Grade         50.0
# Name: 0, dtype: object

# %%
df_students.loc[5, 'Grade']
# Out:
# 3.0

# %%
df_students[df_students['Name'] == 'Vicky']
# Out:
#     Name  StudyHours  Grade
# 5  Vicky         1.0    3.0

# %%
df_students.query('Name=="Vicky"')
# Out:
#     Name  StudyHours  Grade
# 5  Vicky         1.0    3.0

# %%
df_students[df_students.Name=="Vicky"]
# Out:
#     Name  StudyHours  Grade
# 5  Vicky         1.0    3.0

# %%
df_Test = pd.read_csv('Test_data.csv', delimiter=',', header='infer')

# %%
df_Test
# Out:
#       Name  Age  Score
# 0    Alice   25   90.0
# 1      Bob   30    NaN
# 2    Carol   27   78.0
# 3    David   26   65.0
# 4      Eve   22    NaN
# 5    Frank   33   88.0
# 6    Grace   28    NaN
# 7   Hannah   31   82.0
# 8      Ian   35   95.0
# 9    Julia   29    NaN
# 10   Kevin   31   76.0
# 11   Laura   24    NaN
# 12    Mike   30   85.0
# 13    Nina   26    NaN
# 14   Oscar   34   79.0
# 15    Paul   23   64.0
# 16   Quinn   32    NaN
# 17  Rachel   28   70.0
# 18   Steve   27   92.0
# 19    Tina   25    NaN
# 20     Uma   25   86.0
# 21  Victor   30    NaN
# 22   Wendy   29   74.0
# 23  Xander   33    NaN
# 24    Yara   32   89.0
# 25     Zoe   26    NaN

# %%
df_Test.isnull()
# Out:
#      Name    Age  Score
# 0   False  False  False
# 1   False  False   True
# 2   False  False  False
# 3   False  False  False
# 4   False  False   True
# 5   False  False  False
# 6   False  False   True
# 7   False  False  False
# 8   False  False  False
# 9   False  False   True
# 10  False  False  False
# 11  False  False   True
# 12  False  False  False
# 13  False  False   True
# 14  False  False  False
# 15  False  False  False
# 16  False  False   True
# 17  False  False  False
# 18  False  False  False
# 19  False  False   True
# 20  False  False  False
# 21  False  False   True
# 22  False  False  False
# 23  False  False   True
# 24  False  False  False
# 25  False  False   True

# %%
df_Test.isnull().sum()
# Out:
# Name      0
# Age       0
# Score    11
# dtype: int64

# %%
#Filling the null values
df_Test.Score = df_Test.Score.fillna(df_Test.Score.mean())

# %%
df_Test.isnull().sum()
# Out:
# Name     0
# Age      0
# Score    0
# dtype: int64

# %%
#Get the mean age using to column name as an index
mean_age = df_Test['Age'].mean()
mean_score = df_Test['Score'].mean()

#Print the mean age and the mean score
print(f'Average age: {mean_age:.2f}\nAverage score: {mean_score:.2f}')
# Out:
# Average age: 28.50
# Average score: 80.87

# %%
# Finding the student who is younger than the average age
df_Test[df_Test.Age < mean_age]
# Out:
#       Name  Age      Score
# 0    Alice   25  90.000000
# 2    Carol   27  78.000000
# 3    David   26  65.000000
# 4      Eve   22  80.866667
# 6    Grace   28  80.866667
# 11   Laura   24  80.866667
# 13    Nina   26  80.866667
# 15    Paul   23  64.000000
# 17  Rachel   28  70.000000
# 18   Steve   27  92.000000
# 19    Tina   25  80.866667
# 20     Uma   25  86.000000
# 25     Zoe   26  80.866667

# %%
# Finding the average grade value of the students whose age is younger than the average
df_Test[df_Test.Age < mean_age].Score.mean()
# Out:
# 79.24615384615385

# %%
# Setting the condition where students whose grade above 60 are passed
Coundition_Passed = pd.Series(df_Test.Score >= 85)
df_Test = pd.concat([df_Test, Coundition_Passed.rename('Passed')], axis=1)

# %%
df_Test
# Out:
#       Name  Age      Score  Passed
# 0    Alice   25  90.000000    True
# 1      Bob   30  80.866667   False
# 2    Carol   27  78.000000   False
# 3    David   26  65.000000   False
# 4      Eve   22  80.866667   False
# 5    Frank   33  88.000000    True
# 6    Grace   28  80.866667   False
# 7   Hannah   31  82.000000   False
# 8      Ian   35  95.000000    True
# 9    Julia   29  80.866667   False
# 10   Kevin   31  76.000000   False
# 11   Laura   24  80.866667   False
# 12    Mike   30  85.000000    True
# 13    Nina   26  80.866667   False
# 14   Oscar   34  79.000000   False
# 15    Paul   23  64.000000   False
# 16   Quinn   32  80.866667   False
# 17  Rachel   28  70.000000   False
# 18   Steve   27  92.000000    True
# 19    Tina   25  80.866667   False
# 20     Uma   25  86.000000    True
# 21  Victor   30  80.866667   False
# 22   Wendy   29  74.000000   False
# 23  Xander   33  80.866667   False
# 24    Yara   32  89.000000    True
# 25     Zoe   26  80.866667   False

# %%
df_Test.groupby(df_Test.Passed).count()
# Out:
#         Name  Age  Score
# Passed
# False     19   19     19
# True       7    7      7

# %%
df_Test.groupby(df_Test.Passed).Name.count()
# Out:
# Passed
# False    19
# True      7
# Name: Name, dtype: int64

# %%
df_Test.groupby(df_Test.Passed).Score.mean()
# Out:
# Passed
# False    77.764912
# True     89.285714
# Name: Score, dtype: float64

# %%
df_Test.groupby(df_Test.Passed)['Age', 'Score'].count()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2120\2107451907.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_Test.groupby(df_Test.Passed)['Age', 'Score'].count()
#         Age  Score
# Passed
# False    19     19
# True      7      7

# %%
#Sort value by column name with ascending order
df_Test.sort_values('Score')
# Out:
#       Name  Age      Score  Passed
# 15    Paul   23  64.000000   False
# 3    David   26  65.000000   False
# 17  Rachel   28  70.000000   False
# 22   Wendy   29  74.000000   False
# 10   Kevin   31  76.000000   False
# 2    Carol   27  78.000000   False
# 14   Oscar   34  79.000000   False
# 25     Zoe   26  80.866667   False
# 16   Quinn   32  80.866667   False
# 13    Nina   26  80.866667   False
# 21  Victor   30  80.866667   False
# 9    Julia   29  80.866667   False
# 6    Grace   28  80.866667   False
# 23  Xander   33  80.866667   False
# 4      Eve   22  80.866667   False
# 1      Bob   30  80.866667   False
# 11   Laura   24  80.866667   False
# 19    Tina   25  80.866667   False
# 7   Hannah   31  82.000000   False
# 12    Mike   30  85.000000    True
# 20     Uma   25  86.000000    True
# 5    Frank   33  88.000000    True
# 24    Yara   32  89.000000    True
# 0    Alice   25  90.000000    True
# 18   Steve   27  92.000000    True
# 8      Ian   35  95.000000    True

# %%
#Sort value by column name with descending order
df_Test.sort_values('Score', ascending=False)
# Out:
#       Name  Age      Score  Passed
# 8      Ian   35  95.000000    True
# 18   Steve   27  92.000000    True
# 0    Alice   25  90.000000    True
# 24    Yara   32  89.000000    True
# 5    Frank   33  88.000000    True
# 20     Uma   25  86.000000    True
# 12    Mike   30  85.000000    True
# 7   Hannah   31  82.000000   False
# 1      Bob   30  80.866667   False
# 23  Xander   33  80.866667   False
# 21  Victor   30  80.866667   False
# 19    Tina   25  80.866667   False
# 16   Quinn   32  80.866667   False
# 13    Nina   26  80.866667   False
# 11   Laura   24  80.866667   False
# 9    Julia   29  80.866667   False
# 6    Grace   28  80.866667   False
# 4      Eve   22  80.866667   False
# 25     Zoe   26  80.866667   False
# 14   Oscar   34  79.000000   False
# 2    Carol   27  78.000000   False
# 10   Kevin   31  76.000000   False
# 22   Wendy   29  74.000000   False
# 17  Rachel   28  70.000000   False
# 3    David   26  65.000000   False
# 15    Paul   23  64.000000   False
